# %% [markdown]
# <a href="https://colab.research.google.com/github/lnpetrova/comp_ling/blob/master/hw2_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 2.

# %%
import re, collections
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
from nltk import word_tokenize
from gensim.models.phrases import Phrases, Phraser
from gensim.models.word2vec import Text8Corpus
from gensim.test.utils import datapath
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = '''
Аналитики ВЦИОМ попросили россиян дать свои определения понятиям «хороший» и «плохой отец». Чаще всего (37%) «плохими» участники опроса называли пап, которые не занимаются воспитанием детей. Хорошими отцами большая часть опрошенных (30%) считает заботливых мужчин, которые внимательно относятся к семье и ребёнку. Каждый пятый респондент, определяя хорошего отца, на второе и третье места ставили вовлечённость в воспитание и учёбу, а также финансовое обеспечение детей.

Большинство россиян (88%) отвечали, что мужчина в случае развода, расставания и при других сложных обстоятельствах может оставаться хорошим отцом детям от первого брака или самостоятельно воспитывать ребёнка не хуже матери (70%), которая осталась одна.

Мнения респондентов по поводу того, может ли мужчина оставаться хорошим отцом на расстоянии, или же обязательно должен жить рядом, разделились примерно пополам. Молодежь отвечала, что вдали от ребёнка выполнять отцовские функции сложно, а люди старшего возраста считают, что для этого километры не помеха.

95% россиян считают, что папы должны бывать на родительских собраниях. 90% убеждены, что отцы должны помогать ребёнку с творческими заданиями. 88% опрошенных уверены, что отец должен проверять домашние задания. Не менее важно, по мнению респондентов, чтобы отец принимал участие в школьных праздниках (89%) и работе родительского комитета класса (80%).

Около половины (44%) жителей России считают, что отцовство это модно. Так чаще всего думают люди в возрасте от 25 до 34 лет (51%), от 35 до 44 лет (47%), а также те, кто считает свои доходы нормальными или высокими (49%). В «трендовости» отцовства больше всего убеждены жители Москвы, Петербурга и городов-миллионников. С этим утверждением не согласны 38% россиян, в молодёжной группе до 24 лет это каждый второй.


'''

# %%
sentences = sent_tokenize(text)

# %%
print(sentences)
# Out:
# ['\nАналитики ВЦИОМ попросили россиян дать свои определения понятиям «хороший» и «плохой отец».', 'Чаще всего (37%) «плохими» участники опроса называли пап, которые не занимаются воспитанием детей.', 'Хорошими отцами большая часть опрошенных (30%) считает заботливых мужчин, которые внимательно относятся к семье и ребёнку.', 'Каждый пятый респондент, определяя хорошего отца, на второе и третье места ставили вовлечённость в воспитание и учёбу, а также финансовое обеспечение детей.', 'Большинство россиян (88%) отвечали, что мужчина в случае развода, расставания и при других сложных обстоятельствах может оставаться хорошим отцом детям от первого брака или самостоятельно воспитывать ребёнка не хуже матери (70%), которая осталась одна.', 'Мнения респондентов по поводу того, может ли мужчина оставаться хорошим отцом на расстоянии, или же обязательно должен жить рядом, разделились примерно пополам.', 'Молодежь отвечала, что вдали от ребёнка выполнять отцовские функции сложно, а люди старшего
# ...

# %%
def split_text(word): 
    return [char for char in word]

# %%
voc = []
for i in range(len(sentences)):
    voc.append(split_text(sentences[i]))
print(voc)
# Out:
# [['\n', 'А', 'н', 'а', 'л', 'и', 'т', 'и', 'к', 'и', ' ', 'В', 'Ц', 'И', 'О', 'М', ' ', 'п', 'о', 'п', 'р', 'о', 'с', 'и', 'л', 'и', ' ', 'р', 'о', 'с', 'с', 'и', 'я', 'н', ' ', 'д', 'а', 'т', 'ь', ' ', 'с', 'в', 'о', 'и', ' ', 'о', 'п', 'р', 'е', 'д', 'е', 'л', 'е', 'н', 'и', 'я', ' ', 'п', 'о', 'н', 'я', 'т', 'и', 'я', 'м', ' ', '«', 'х', 'о', 'р', 'о', 'ш', 'и', 'й', '»', ' ', 'и', ' ', '«', 'п', 'л', 'о', 'х', 'о', 'й', ' ', 'о', 'т', 'е', 'ц', '»', '.'], ['Ч', 'а', 'щ', 'е', ' ', 'в', 'с', 'е', 'г', 'о', ' ', '(', '3', '7', '%', ')', ' ', '«', 'п', 'л', 'о', 'х', 'и', 'м', 'и', '»', ' ', 'у', 'ч', 'а', 'с', 'т', 'н', 'и', 'к', 'и', ' ', 'о', 'п', 'р', 'о', 'с', 'а', ' ', 'н', 'а', 'з', 'ы', 'в', 'а', 'л', 'и', ' ', 'п', 'а', 'п', ',', ' ', 'к', 'о', 'т', 'о', 'р', 'ы', 'е', ' ', 'н', 'е', ' ', 'з', 'а', 'н', 'и', 'м', 'а', 'ю', 'т', 'с', 'я', ' ', 'в', 'о', 'с', 'п', 'и', 'т', 'а', 'н', 'и', 'е', 'м', ' ', 'д', 'е', 'т', 'е', 'й', '.'], ['Х', 'о', 'р', 'о', 'ш', 'и', 'м', 'и', '
# ...

# %%
phrases = Phrases(voc, min_count = 1, scoring = 'npmi', threshold = 0)

# %%
p1=Phrases (phrases[voc], scoring = 'npmi', threshold = -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
p2=Phrases (p1[phrases[voc]],scoring = 'npmi', threshold = -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
p3=Phrases (p2[p0[phrases[voc]]], scoring = 'npmi', threshold = -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
print(list(p3[p2[p1[voc]]]))
# Out:
# [['\n', 'А', 'н_а', 'л_и', 'т', 'и', 'к', 'и_ ', 'В', 'Ц', 'И', 'О', 'М', ' _п', 'о', 'п_р', 'о_с', 'и_л_и_ ', 'р_о', 'с', 'с', 'и', 'я', 'н', ' _д', 'а', 'т', 'ь', ' _с', 'в_о', 'и_ ', 'о', 'п_р', 'е', 'д_е', 'л_е', 'н_и', 'я', ' _п', 'о', 'н', 'я', 'т', 'и', 'я', 'м_ ', '«', 'х_о', 'р_о', 'ш', 'и', 'й', '»', ' ', 'и_ ', '«', 'п', 'л', 'о', 'х_о', 'й', ' _о', 'т_е', 'ц', '»', '.'], ['Ч', 'а', 'щ', 'е_ ', 'в', 'с', 'е', 'г', 'о_ ', '(', '3', '7', '%', ')', ' ', '«', 'п', 'л', 'о', 'х', 'и_м', 'и', '»', ' ', 'у', 'ч', 'а', 'с_т', 'н_и', 'к', 'и_ ', 'о', 'п_р', 'о_с', 'а_ ', 'н_а', 'з', 'ы', 'в', 'а', 'л_и', ' _п', 'а', 'п', ',', ' _к', 'о_т', 'о', 'р', 'ы', 'е_ ', 'н_е', ' ', 'з', 'а', 'н_и', 'м', 'а', 'ю', 'т', 'с', 'я', ' _в', 'о_с', 'п', 'и_т', 'а', 'н_и', 'е', 'м_ ', 'д_е', 'т_е', 'й', '.'], ['Х', 'о', 'р_о', 'ш', 'и_м', 'и_ ', 'о_т', 'ц', 'а', 'м', 'и_ ', 'б', 'о_л', 'ь', 'ш', 'а', 'я', ' ', 'ч', 'а', 'с_т', 'ь', ' _о', 'п_р', 'о', 'ш', 'е_н', 'н', 'ы', 'х_ ', '(', '3', '0', '%',
# ...

# %%
phrases_input = phrases[voc]
for i in range(10):
    phrases = Phrases(phrases_input, min_count=1, scoring='npmi', threshold=-1)
    phrases_input = phrases[phrases_input]
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
print(list(phrases[phrases_input]))
# Out:
# [['\n_А_н_а_л_и_т_и_к_и_ _В_Ц_И_О_М_ _п_о_п_р_о_с_и_л_и_ _р_о_с_с_и_я_н_ _д_а_т_ь_ _с_в_о_и_ _о_п_р_е_д_е_л_е_н_и_я_ _п_о_н_я_т_и_я_м_ _«_х_о_р_о_ш_и_й_»_ _и_ _«_п_л_о_х_о_й_ _о_т_е_ц_»_.'], ['Ч_а_щ_е_ _в_с_е_г_о_ _(_3_7_%_)_ _«_п_л_о_х_и_м_и_»_ _у_ч_а_с_т_н_и_к_и_ _о_п_р_о_с_а_ _н_а_з_ы_в_а_л_и_ _п_а_п_,_ _к_о_т_о_р_ы_е_ _н_е_ _з_а_н_и_м_а_ю_т_с_я_ _в_о_с_п_и_т_а_н_и_е_м_ _д_е_т_е_й_.'], ['Х_о_р_о_ш_и_м_и_ _о_т_ц_а_м_и_ _б_о_л_ь_ш_а_я_ _ч_а_с_т_ь_ _о_п_р_о_ш_е_н_н_ы_х_ _(_3_0_%_)_ _с_ч_и_т_а_е_т_ _з_а_б_о_т_л_и_в_ы_х_ _м_у_ж_ч_и_н_,_ _к_о_т_о_р_ы_е_ _в_н_и_м_а_т_е_л_ь_н_о_ _о_т_н_о_с_я_т_с_я_ _к_ _с_е_м_ь_е_ _и_ _р_е_б_ё_н_к_у_.'], ['К_а_ж_д_ы_й_ _п_я_т_ы_й_ _р_е_с_п_о_н_д_е_н_т_,_ _о_п_р_е_д_е_л_я_я_ _х_о_р_о_ш_е_г_о_ _о_т_ц_а_,_ _н_а_ _в_т_о_р_о_е_ _и_ _т_р_е_т_ь_е_ _м_е_с_т_а_ _с_т_а_в_и_л_и_ _в_о_в_л_е_ч_ё_н_н_о_с_т_ь_ _в_ _в_о_с_п_и_т_а_н_и_е_ _и_ _у_ч_ё_б_у_,_ _а_ _т_а_к_ж_е_ _ф_и_н_а_н_с_о_в_о_е_ _о_б_е_с_п_е_ч_е_н_и_е_ _д_е_т_е_й_.'], ['Б_о_л_ь_ш_и_н_с_т_в_о_ _р_о_с_с_и_я_н_
# ...
