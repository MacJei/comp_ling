# %%
import string
from gensim.utils import tokenize
from gensim.summarization.textcleaner import split_sentences
from nltk import sent_tokenize
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from pymorphy2 import MorphAnalyzer
from pymystem3 import Mystem
from nltk.corpus import stopwords
from string import punctuation
import re, os, json
mystem = Mystem()
morph = MorphAnalyzer()
# Out:
# Installing mystem to /home/postyakov/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz

# %%
#Задание2
text = '''
Обособление обстоятельств
Обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. Обстоятельства поясняют сказуемые или другие члены предложения. При синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). Обстоятельства необходимо выделять запятыми в трех случаях. Рассмотрим каждый из них по очереди.

Первый случай

Обстоятельства в предложениях могут быть выражены четырьмя частями речи: 

наречием, например: Дворник встает рано;
деепричастием или деепричастным оборотом, например: Мужики, увидев помещика, сняли шапки;
инфинитивом, например: Все отправились на улицу (зачем?) расчищать снег; 
существительным, например: Я приехал в столицу (зачем?) на экскурсию.
Кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: Дождь шел две недели подряд.

Необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборотом. Сравните: Он сидел, листая журнал, и скучал и Он сидел на скамейке. В первом предложении обстоятельство листая журнал выделяется, так как оно выражено деепричастным оборотом, а во втором обстоятельство на скамейке не обособляется, так как оно выражено существительным с предлогом.

Второй и третий случаи

По значению обстоятельства делятся на следующие основные группы: 

обстоятельства места, отвечающие на вопросы ГДЕ? КУДА? ОТКУДА? Например: Мы въехали (куда?) в город; 
обстоятельства времени, отвечающие на вопросы КОГДА? С КАКИХ ПОР? ДО КАКИХ ПОР? КАК ДОЛГО? Например: Мы прождали их около двух часов;
обстоятельства причины, которые отвечают на вопросы ПОЧЕМУ? ОТЧЕГО? ПО КАКОЙ ПРИЧИНЕ? Например: От усталости я не мог говорить; 
обстоятельства цели, которые отвечают на вопросы ЗАЧЕМ? ДЛЯ ЧЕГО? С КАКОЙ ЦЕЛЬЮ? Например: В санатории все приготовлено для лечения отдыхающих;
обстоятельства образа действия и степени, отвечающие на вопросы КАК? КАКИМ ОБРАЗОМ? В КАКОЙ СТЕПЕНИ? Например: Я несколько призадумался или Отец ни на шаг не отпускал меня;
обстоятельства условия, которые отвечают на вопрос ПРИ КАКОМ УСЛОВИИ? Например: При старании можно добиться успеха; 
обстоятельства уступки, которые отвечают на вопрос НЕСМОТРЯ НА ЧТО? Например: На улице, несмотря на мороз, было многолюдно; 
обстоятельства сравнения, отвечающие на вопрос КАК? Например: Голова у нее острижена, как у мальчишки.
В классификации обстоятельств по значению одним из восьми видов являются обстоятельства сравнения: они отвечают на вопрос КАК? и начинается с союзов КАК, СЛОВНО или БУДТО. Например: У нее были длинные волосы, мягкие, как лен. В некоторых учебниках и справочных пособиях обстоятельства сравнения называют также сравнительными оборотами. Необходимо запомнить, что обстоятельства сравнения в предложениях выделяются запятыми.

Еще один вид обстоятельств, который необходимо выделять запятыми, это обстоятельства уступки. Такие обстоятельства отвечают на вопрос НЕСМОТРЯ НА ЧТО? и начинаются с предлога НЕСМОТРЯ НА (или, реже, ВОПРЕКИ). Например: На улицах, несмотря на яркое солнце, горели фонари.

Итак, следует запомнить три случая, когда обстоятельства необходимо выделять запятыми: 

если они выражены деепричастным оборотом, 
если они представляют собой сравнительный оборот, 
если они начинаются с предлога НЕСМОТРЯ НА.
Еще раз рассмотрите примеры. Сверкая быстро в вышине, кружились искры. (Лермонтов) Она вдруг скрылась, как птичка, вспугнутая из кустарника (Лермонтов). Несмотря на непредвиденные трудности, работа закончена в срок.

Это правило имеет несколько важных примечаний: 

От деепричастий следует отличать наречия СТОЯ, СИДЯ, ЛЕЖА, МОЛЧА. НЕХОТЯ, ШУТЯ, НЕ ГЛЯДЯ, ИГРАЯ. Они образовались благодаря переходу слов из разряда деепричастий в наречия. Обстоятельства, выраженные такими словами, не обособляются. Например: Он стоял молча. 

Не выделяются также обстоятельства, выраженные фразеологическими оборотами, например: Они работали засучив рукава или Верчусь целый день как белка в колесе. 

Кроме обстоятельств уступки, которые выделяются всегда, могут факультативно обособляться обстоятельства, выраженные существительными с производными предлогами БЛАГОДАРЯ, СОГЛАСНО, ВОПРЕКИ, ВВИДУ, ВСЛЕДСТВИЕ, например: Благодаря хорошей погоде, мы купались в реке все лето. Обычно такие обстоятельства обособляются, если они распространены и стоят перед сказуемым.
'''
text = text.lower() 
print(text)
# Out:
# обособление обстоятельств
# обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. обстоятельства поясняют сказуемые или другие члены предложения. при синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). обстоятельства необходимо выделять запятыми в трех случаях. рассмотрим каждый из них по очереди.
#
# первый случай
#
# обстоятельства в предложениях могут быть выражены четырьмя частями речи:
#
# наречием, например: дворник встает рано;
# деепричастием или деепричастным оборотом, например: мужики, увидев помещика, сняли шапки;
# инфинитивом, например: все отправились на улицу (зачем?) расчищать снег;
# существительным, например: я приехал в столицу (зачем?) на экскурсию.
# кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: дождь шел две недели подряд.
#
# необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборотом. сравните: он сидел, листая журнал, и скучал и он сидел на скамейке. в первом предложении обстоятельство листая журнал выделяется, так как оно выражено деепричастным оборотом, а во втором обстоятельство на скамейке не обособляется, так как оно выражено существительным с предлогом.
#
# второй и третий случаи
#
# по значению обстоятельства делятся на следующие основные группы:
#
# обстоятельства места, отвечающие на вопросы где? куда? откуда? например: мы въехали (куда?) в город;
# обстоятельства времени, отвечающие на вопросы когда? с каких пор? до каких пор? как долго? например: мы прождали их около двух часов;
# обстоятельства причины, которые отвечают на вопросы почему? отчего? по какой причине? например: от усталости я не мог говорить;
# обстоятельства цели, которые отвечают на вопросы зачем? для чего? с какой целью? например: в санатории все приготовлено для лечения отдыхающих;
# обстоятельства образа действия и степени, отвечающие на вопросы как? каким образом? в какой степени? например: я несколько призадумался или отец ни на шаг не отпускал меня;
# обстоятельства условия, которые отвечают на вопрос при каком условии? например: при старании можно добиться успеха;
# обстоятельства уступки, которые отвечают на вопрос несмотря на что? например: на улице, несмотря на мороз, было многолюдно;
# обстоятельства сравнения, отвечающие на вопрос как? например: голова у нее острижена, как у мальчишки.
# в классификации обстоятельств по значению одним из восьми видов являются обстоятельства сравнения: они отвечают на вопрос как? и начинается с союзов как, словно или будто. например: у нее были длинные волосы, мягкие, как лен. в некоторых учебниках и справочных пособиях обстоятельства сравнения называют также сравнительными оборотами. необходимо запомнить, что обстоятельства сравнения в предложениях выделяются запятыми.
#
# еще один вид обстоятельств, который необходимо выделять запятыми, это обстоятельства уступки. такие обстоятельства отвечают на вопрос несмотря на что? и начинаются с предлога несмотря на (или, реже, вопреки). например: на улицах, несмотря на яркое солнце, горели фонари.
#
# итак, следует запомнить три случая, когда обстоятельства необходимо выделять запятыми:
#
# если они выражены деепричастным оборотом,
# если они представляют собой сравнительный оборот,
# если они начинаются с предлога несмотря на.
# еще раз рассмотрите примеры. сверкая быстро в вышине, кружились искры. (лермонтов) она вдруг скрылась, как птичка, вспугнутая из кустарника (лермонтов). несмотря на непредвиденные трудности, работа закончена в срок.
#
# это правило имеет несколько важных примечаний:
#
# от деепричастий следует отличать наречия стоя, сидя, лежа, молча. нехотя, шутя, не глядя, играя. они образовались благодаря переходу слов из разряда деепричастий в наречия. обстоятельства, выраженные такими словами, не обособляются. например: он стоял молча.
#
# не выделяются также обстоятельства, выраженные фразеологическими оборотами, например: они работали засучив рукава или верчусь целый день как белка в колесе.
#
# кроме обстоятельств уступки, которые выделяются всегда, могут факультативно обособляться обстоятельства, выраженные существительными с производными предлогами благодаря, согласно, вопреки, ввиду, вследствие, например: благодаря хорошей погоде, мы купались в реке все лето. обычно такие обстоятельства обособляются, если они распространены и стоят перед сказуемым.

# %%
string.punctuation += '–'
delete_punctuation = [word.strip(string.punctuation) for word in text.split()]
print(delete_punctuation)
# Out:
# ['обособление', 'обстоятельств', 'обстоятельство', '', 'второстепенный', 'член', 'предложения', 'который', 'обозначает', 'признак', 'действия', 'или', 'другого', 'признака', 'обстоятельства', 'поясняют', 'сказуемые', 'или', 'другие', 'члены', 'предложения', 'при', 'синтаксическом', 'разборе', 'предложения', 'обстоятельства', 'подчеркиваются', 'пунктирной', 'линией', 'тире', 'точка', 'тире', 'обстоятельства', 'необходимо', 'выделять', 'запятыми', 'в', 'трех', 'случаях', 'рассмотрим', 'каждый', 'из', 'них', 'по', 'очереди', 'первый', 'случай', 'обстоятельства', 'в', 'предложениях', 'могут', 'быть', 'выражены', 'четырьмя', 'частями', 'речи', 'наречием', 'например', 'дворник', 'встает', 'рано', 'деепричастием', 'или', 'деепричастным', 'оборотом', 'например', 'мужики', 'увидев', 'помещика', 'сняли', 'шапки', 'инфинитивом', 'например', 'все', 'отправились', 'на', 'улицу', 'зачем', 'расчищать', 'снег', 'существительным', 'например', 'я', 'приехал', 'в', 'столицу', 'зачем', 'на', 'экскурсию', 'кроме', 'этого', 'обстоятельство', 'может', 'быть', 'выражено', 'цельным', 'по', 'смыслу', 'выражением', 'например', 'дождь', 'шел', 'две', 'недели', 'подряд', 'необходимо', 'запомнить', 'что', 'выделять', 'запятыми', 'нужно', 'обстоятельства', 'которые', 'выражены', 'деепричастием', 'или', 'деепричастным', 'оборотом', 'сравните', 'он', 'сидел', 'листая', 'журнал', 'и', 'скучал', 'и', 'он', 'сидел', 'на', 'скамейке', 'в', 'первом', 'предложении', 'обстоятельство', 'листая', 'журнал', 'выделяется', 'так', 'как', 'оно', 'выражено', 'деепричастным', 'оборотом', 'а', 'во', 'втором', 'обстоятельство', 'на', 'скамейке', 'не', 'обособляется', 'так', 'как', 'оно', 'выражено', 'существительным', 'с', 'предлогом', 'второй', 'и', 'третий', 'случаи', 'по', 'значению', 'обстоятельства', 'делятся', 'на', 'следующие', 'основные', 'группы', 'обстоятельства', 'места', 'отвечающие', 'на', 'вопросы', 'где', 'куда', 'откуда', 'например', 'мы', 'въехали', 'куда', 'в', 'город', 'обстоятельства', 'времени', 'отвечающие', 'на', 'вопросы', 'когда', 'с', 'каких', 'пор', 'до', 'каких', 'пор', 'как', 'долго', 'например', 'мы', 'прождали', 'их', 'около', 'двух', 'часов', 'обстоятельства', 'причины', 'которые', 'отвечают', 'на', 'вопросы', 'почему', 'отчего', 'по', 'какой', 'причине', 'например', 'от', 'усталости', 'я', 'не', 'мог', 'говорить', 'обстоятельства', 'цели', 'которые', 'отвечают', 'на', 'вопросы', 'зачем', 'для', 'чего', 'с', 'какой', 'целью', 'например', 'в', 'санатории', 'все', 'приготовлено', 'для', 'лечения', 'отдыхающих', 'обстоятельства', 'образа', 'действия', 'и', 'степени', 'отвечающие', 'на', 'вопросы', 'как', 'каким', 'образом', 'в', 'какой', 'степени', 'например', 'я', 'несколько', 'призадумался', 'или', 'отец', 'ни', 'на', 'шаг', 'не', 'отпускал', 'меня', 'обстоятельства', 'условия', 'которые', 'отвечают', 'на', 'вопрос', 'при', 'каком', 'условии', 'например', 'при', 'старании', 'можно', 'добиться', 'успеха', 'обстоятельства', 'уступки', 'которые', 'отвечают', 'на', 'вопрос', 'несмотря', 'на', 'что', 'например', 'на', 'улице', 'несмотря', 'на', 'мороз', 'было', 'многолюдно', 'обстоятельства', 'сравнения', 'отвечающие', 'на', 'вопрос', 'как', 'например', 'голова', 'у', 'нее', 'острижена', 'как', 'у', 'мальчишки', 'в', 'классификации', 'обстоятельств', 'по', 'значению', 'одним', 'из', 'восьми', 'видов', 'являются', 'обстоятельства', 'сравнения', 'они', 'отвечают', 'на', 'вопрос', 'как', 'и', 'начинается', 'с', 'союзов', 'как', 'словно', 'или', 'будто', 'например', 'у', 'нее', 'были', 'длинные', 'волосы', 'мягкие', 'как', 'лен', 'в', 'некоторых', 'учебниках', 'и', 'справочных', 'пособиях', 'обстоятельства', 'сравнения', 'называют', 'также', 'сравнительными', 'оборотами', 'необходимо', 'запомнить', 'что', 'обстоятельства', 'сравнения', 'в', 'предложениях', 'выделяются', 'запятыми', 'еще', 'один', 'вид', 'обстоятельств', 'который', 'необходимо', 'выделять', 'запятыми', 'это', 'обстоятельства', 'уступки', 'такие', 'обстоятельства', 'отвечают', 'на', 'вопрос ...

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer('russian')

# %%
[(word, stemmer.stem(word)) for word in delete_punctuation]
# Out:
# [('обособление', 'обособлен'),
#  ('обстоятельств', 'обстоятельств'),
#  ('обстоятельство', 'обстоятельств'),
#  ('', ''),
#  ('второстепенный', 'второстепен'),
#  ('член', 'член'),
#  ('предложения', 'предложен'),
#  ('который', 'котор'),
#  ('обозначает', 'обознача'),
#  ('признак', 'признак'),
#  ('действия', 'действ'),
#  ('или', 'ил'),
#  ('другого', 'друг'),
#  ('признака', 'признак'),
#  ('обстоятельства', 'обстоятельств'),
#  ('поясняют', 'поясня'),
#  ('сказуемые', 'сказуем'),
#  ('или', 'ил'),
#  ('другие', 'друг'),
#  ('члены', 'член'),
#  ('предложения', 'предложен'),
#  ('при', 'при'),
#  ('синтаксическом', 'синтаксическ'),
#  ('разборе', 'разбор'),
#  ('предложения', 'предложен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('подчеркиваются', 'подчеркива'),
#  ('пунктирной', 'пунктирн'),
#  ('линией', 'лин'),
#  ('тире', 'тир'),
#  ('точка', 'точк'),
#  ('тире', 'тир'),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('в', 'в'),
#  ('трех', 'трех'),
#  ('случаях', 'случа'),
#  ('рассмотрим', 'рассмотр'),
#  ('каждый', 'кажд'),
#  ('из', 'из'),
#  ('них', 'них'),
#  ('по', 'по'),
#  ('очереди', 'очеред'),
#  ('первый', 'перв'),
#  ('случай', 'случа'),
#  ('обстоятельства', 'обстоятельств'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('могут', 'могут'),
#  ('быть', 'быт'),
#  ('выражены', 'выраж'),
#  ('четырьмя', 'четырьм'),
#  ('частями', 'част'),
#  ('речи', 'реч'),
#  ('наречием', 'нареч'),
#  ('например', 'например'),
#  ('дворник', 'дворник'),
#  ('встает', 'встает'),
#  ('рано', 'ран'),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('например', 'например'),
#  ('мужики', 'мужик'),
#  ('увидев', 'увид'),
#  ('помещика', 'помещик'),
#  ('сняли', 'снял'),
#  ('шапки', 'шапк'),
#  ('инфинитивом', 'инфинитив'),
#  ('например', 'например'),
#  ('все', 'все'),
#  ('отправились', 'отправ'),
#  ('на', 'на'),
#  ('улицу', 'улиц'),
#  ('зачем', 'зач'),
#  ('расчищать', 'расчища'),
#  ('снег', 'снег'),
#  ('существительным', 'существительн'),
#  ('например', 'например'),
#  ('я', 'я'),
#  ('приехал', 'приеха'),
#  ('в', 'в'),
#  ('столицу', 'столиц'),
#  ('зачем', 'зач'),
#  ('на', 'на'),
#  ('экскурсию', 'экскурс'),
#  ('кроме', 'кром'),
#  ('этого', 'эт'),
#  ('обстоятельство', 'обстоятельств'),
#  ('может', 'может'),
#  ('быть', 'быт'),
#  ('выражено', 'выраж'),
#  ('цельным', 'цельн'),
#  ('по', 'по'),
#  ('смыслу', 'смысл'),
#  ('выражением', 'выражен'),
#  ('например', 'например'),
#  ('дождь', 'дожд'),
#  ('шел', 'шел'),
#  ('две', 'две'),
#  ('недели', 'недел'),
#  ('подряд', 'подряд'),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('что', 'что'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('нужно', 'нужн'),
#  ('обстоятельства', 'обстоятельств'),
#  ('которые', 'котор'),
#  ('выражены', 'выраж'),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('сравните', 'сравн'),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('и', 'и'),
#  ('скучал', 'скуча'),
#  ('и', 'и'),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('в', 'в'),
#  ('первом', 'перв'),
#  ('предложении', 'предложен'),
#  ('обстоятельство', 'обстоятельств'),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('выделяется', 'выделя'),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('а', 'а'),
#  ('во', 'во'),
#  ('втором', 'втор'),
#  ('обстоятельство', 'обстоятельств'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('не', 'не'),
#  ('обособляется', 'обособля'),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('существительным', 'существительн'),
#  ('с', 'с'),
#  ('предлогом', 'предлог'),
#  ('второй', 'втор'),
#  ('и', 'и'),
#  ('третий', 'трет'),
#  ('случаи', 'случа'),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('делятся', 'дел'),
#  ('на', 'на'),
#  ('следующие', 'след'),
#  ('основные', 'основн'),
#  ('группы', 'групп'),
#  ('обстоятельства', 'обстоятельств'),
#  ('места', 'мест'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('где', 'где'),
#  ('куда', 'куд'),
#  ('откуда', 'откуд'),
#  ('например', 'например'),
#  ('мы', 'мы'),
#  ('въехали', 'въеха'),
#  ('куда', 'куд'),
#  ('в', 'в'),
#  ('город', 'город'),
#  ('обстоятельства', 'обстоятельств'),
#  ('времени', 'времен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('когда', 'когд'),
#  ('с', 'с'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('до', 'до'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('как', 'как'),
#  ('долго', 'долг'),
#  ('например', 'например'),
#  ('мы', 'мы'),
#  ('прождали', 'прожда'),
#  ('их', 'их'),
#  ('около', 'окол'),
#  ('двух', 'двух'),
#  ('часов', 'час'),
#  ('обстоятельства', 'обстоятельств'),
#  ('причины', 'причин'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('почему', 'поч'),
#  ('отчего', 'отч'),
#  ('по', 'по'),
#  ('какой', 'как'),
#  ('причине', 'причин'),
#  ('например', 'например'),
#  ('от', 'от'),
#  ('усталости', 'устал'),
#  ('я', 'я'),
#  ('не', 'не'),
#  ('мог', 'мог'),
#  ('говорить', 'говор'),
#  ('обстоятельства', 'обстоятельств'),
#  ('цели', 'цел'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('зачем', 'зач'),
#  ('для', 'для'),
#  ('чего', 'чег'),
#  ('с', 'с'),
#  ('какой', 'как'),
#  ('целью', 'цел'),
#  ('например', 'например'),
#  ('в', 'в'),
#  ('санатории', 'санатор'),
#  ('все', 'все'),
#  ('приготовлено', 'приготовл'),
#  ('для', 'для'),
#  ('лечения', 'лечен'),
#  ('отдыхающих', 'отдыха'),
#  ('обстоятельства', 'обстоятельств'),
#  ('образа', 'образ'),
#  ('действия', 'действ'),
#  ('и', 'и'),
#  ('степени', 'степен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('как', 'как'),
#  ('каким', 'как'),
#  ('образом', 'образ'),
#  ('в', 'в'),
#  ('какой', 'как'),
#  ('степени', 'степен'),
#  ('например', 'например'),
#  ('я', 'я'),
#  ('несколько', 'нескольк'),
#  ('призадумался', 'призадума'),
#  ('или', 'ил'),
#  ('отец', 'отец'),
#  ('ни', 'ни'),
#  ('на', 'на'),
#  ('шаг', 'шаг'),
#  ('не', 'не'),
#  ('отпускал', 'отпуска'),
#  ('меня', 'мен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('условия', 'услов'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('при', 'при'),
#  ('каком', 'как'),
#  ('условии', 'услов'),
#  ('например', 'например'),
#  ('при', 'при'),
#  ('старании', 'старан'),
#  ('можно', 'можн'),
#  ('добиться', 'доб'),
#  ('успеха', 'успех'),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('например', 'например'),
#  ('на', 'на'),
#  ('улице', 'улиц'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('мороз', 'мороз'),
#  ('было', 'был'),
#  ('многолюдно', 'многолюдн'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('например', 'например'),
#  ('голова', 'голов'),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('острижена', 'остриж'),
#  ('как', 'как'),
#  ('у', 'у'),
#  ('мальчишки', 'мальчишк'),
#  ('в', 'в'),
#  ('классификации', 'классификац'),
#  ('обстоятельств', 'обстоятельств'),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('одним', 'одн'),
#  ('из', 'из'),
#  ('восьми', 'восьм'),
#  ('видов', 'вид'),
#  ('являются', 'явля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('они', 'он'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('и', 'и'),
#  ('начинается', 'начина'),
#  ('с', 'с'),
#  ('союзов', 'союз'),
#  ('как', 'как'),
#  ('словно', 'словн'),
#  ('или', 'ил'),
#  ('будто', 'будт'),
#  ('например', 'например'),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('были', 'был'),
#  ('длинные', 'длин'),
#  ('волосы', 'волос'),
#  ('мягкие', 'мягк'),
#  ('как', 'как'),
#  ('лен', 'лен'),
#  ('в', 'в'),
#  ('некоторых', 'некотор'),
#  ('учебниках', 'учебник'),
#  ('и', 'и'),
#  ('справочных', 'справочн'),
#  ('пособиях', 'пособ'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('называют', 'называ'),
#  ('также', 'такж'),
#  ('сравнительными', 'сравнительн'),
#  ('оборотами', 'оборот'),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('что', 'что'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('выделяются', 'выделя'),
#  ('запятыми', 'запят'),
#  ('еще', 'ещ'),
#  ('один', 'один'),
#  ('вид', 'вид'),
#  ('обстоятельств', 'обстоятельств'),
#  ('который', 'котор'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('это', 'эт'),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('и', 'и'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('или', 'ил'),
#  ('реже', 'реж'),
#  ('вопреки', 'вопрек'),
#  ('например', 'например'),
#  ('на', 'на'),
#  ('улицах', 'улиц'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('яркое', 'ярк'),
#  ('солнце', 'солнц'),
#  ('горели', 'горел'),
#  ('фонари', 'фонар'),
#  ('итак', 'итак'),
#  ('следует', 'след'),
#  ('запомнить', 'запомн'),
#  ('три', 'три'),
#  ('случая', 'случ'),
#  ('когда', 'когд'),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('выражены', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('представляют', 'представля'),
#  ('собой', 'соб'),
#  ('сравнительный', 'сравнительн'),
#  ('оборот', 'оборот'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('еще', 'ещ'),
#  ('раз', 'раз'),
#  ('рассмотрите', 'рассмотр'),
#  ('примеры', 'пример'),
#  ('сверкая', 'сверк'),
#  ('быстро', 'быстр'),
#  ('в', 'в'),
#  ('вышине', 'вышин'),
#  ('кружились', 'круж'),
#  ('искры', 'искр'),
#  ('лермонтов', 'лермонт'),
#  ('она', 'он'),
#  ('вдруг', 'вдруг'),
#  ('скрылась', 'скрыл'),
#  ('как', 'как'),
#  ('птичка', 'птичк'),
#  ('вспугнутая', 'вспугнут'),
#  ('из', 'из'),
#  ('кустарника', 'кустарник'),
#  ('лермонтов', 'лермонт'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('непредвиденные', 'непредвиден'),
#  ('трудности', 'трудност'),
#  ('работа', 'работ'),
#  ('закончена', 'законч'),
#  ('в', 'в'),
#  ('срок', 'срок'),
#  ('это', 'эт'),
#  ('правило', 'прав'),
#  ('имеет', 'имеет'),
#  ('несколько', 'нескольк'),
#  ('важных', 'важн'),
#  ('примечаний', 'примечан'),
#  ('от', 'от'),
#  ('деепричастий', 'деепричаст'),
#  ('следует', 'след'),
#  ('отличать', 'отлича'),
#  ('наречия', 'нареч'),
#  ('стоя', 'сто'),
#  ('сидя', 'сид'),
#  ('лежа', 'леж'),
#  ('молча', 'молч'),
#  ('нехотя', 'нехот'),
#  ('шутя', 'шут'),
#  ('не', 'не'),
#  ('глядя', 'гляд'),
#  ('играя', 'игр'),
#  ('они', 'он'),
#  ('образовались', 'образова'),
#  ('благодаря', 'благодар'),
#  ('переходу', 'переход'),
#  ('слов', 'слов'),
#  ('из', 'из'),
#  ('разряда', 'разряд'),
#  ('деепричастий', 'деепричаст'),
#  ('в', 'в'),
#  ('наречия', 'нареч'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('такими', 'так'),
#  ('словами', 'слов'),
#  ('не', 'не'),
#  ('обособляются', 'обособля'),
#  ('например', 'например'),
#  ('он', 'он'),
#  ('стоял', 'стоя'),
#  ('молча', 'молч'),
#  ('не', 'не'),
#  ('выделяются', 'выделя'),
#  ('также', 'такж'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('фразеологическими', 'фразеологическ'),
#  ('оборотами', 'оборот'),
#  ('например', 'например'),
#  ('они', 'он'),
#  ('работали', 'работа'),
#  ('засучив', 'засуч'),
#  ('рукава', 'рукав'),
#  ('или', 'ил'),
#  ('верчусь', 'верч'),
#  ('целый', 'цел'),
#  ('день', 'ден'),
#  ('как', 'как'),
#  ('белка', 'белк'),
#  ('в', 'в'),
#  ('колесе', 'колес'),
#  ('кроме', 'кром'),
#  ('обстоятельств', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('которые', 'котор'),
#  ('выделяются', 'выделя'),
#  ('всегда', 'всегд'),
#  ('могут', 'могут'),
#  ('факультативно', 'факультативн'),
#  ('обособляться', 'обособля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('существительными', 'существительн'),
#  ('с', 'с'),
#  ('производными', 'производн'),
#  ('предлогами', 'предлог'),
#  ('благодаря', 'благодар'),
#  ('согласно', 'согласн'),
#  ('вопреки', 'вопрек'),
#  ('ввиду', 'ввид'),
#  ('вследствие', 'вследств'),
#  ('например', 'например'),
#  ('благодаря', 'благодар'),
#  ('хорошей', 'хорош'),
#  ('погоде', 'погод'),
#  ('мы', 'мы'),
#  ('купались', 'купа'),
#  ('в', 'в'),
#  ('реке', 'рек'),
#  ('все', 'все'),
#  ('лето', 'лет'),
#  ('обычно', 'обычн'),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обособляются', 'обособля'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('распространены', 'распростран'),
#  ('и', 'и'),
#  ('стоят', 'сто'),
#  ('перед', 'перед'),
#  ('сказуемым', 'сказуем')]

# %% [markdown]
# Примеры:
# 1. Два разных слова ошибочно свелись к одинаковой основе:слова "не" и "нее" свелись к основе "не"; слова "он" и "они" свелись к основе "он",
# 2. Два словоформы одного слова после стемминга отличаются друг от друга: "предложениях" - "предложен" / "предложения" - "предложения"; "выделять" - "выделя" / "выделяется" - "выделяется"; "обособляться" - "обособля / обособляются" - "обособляются"
# 3. Слово не изменилось после стемминга (слово должно быть русским и длиннее 4 символов): "oбстоятельства" - "обстоятельства", "примечаний" - "примечаний", "трудности" - "трудности", "примеры" - "примеры","вышине" - "вышине" и т.д.

# %%
#Задание_4
text1 = '''​«Новая газета» опубликовала сокращенный вариант заключения экспертов Александра Коршикова и Анны Осокиной, которые анализировали видео из блога студента Высшей школы экономики Егора Жукова, обвиняемого в призывах к экстремизму в интернете (часть 2 статьи 280 УК).

Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова. По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».

В заключении говорится, что Жуков приписывает действующей власти «враждебные действия», называет ее врагами, источником зла и вреда. Кроме того, студент призывает с этой властью бороться.

«Автор описывает катастрофическое положение населения в России, как следствие целенаправленной политики действующей власти <...>. Основным идеалом, которого следует достичь, является "смена власти в России" для того, чтобы "Россия стала свободной"», — цитирует издание экспертов.

В одном из видео, в котором Жуков размышлял об итогах митинга 7 октября 2017 года, эксперты увидели призыв бороться любым способом, «что включает в себя и действия насильственного характера, в частности, насильственный захват власти, вооруженный мятеж».

Егор Жуков — фигурант «московского дела». Сначала его обвиняли в участии в массовых беспорядках (часть 2 статьи 212 УК). В суде говорили, что среди материалов есть видео, где Жуков показывает кому-то направо на акции 27 июля. Из-за этого студента 2 августа отправили в СИЗО.

Однако через месяц дело о массовых беспорядках против Жукова закрыли, ему предъявили новое обвинение в призывах к экстремизму. По ходатайстве следствие суд перевел студента под домашний арест.'''
import nltk
nltk.download('punkt')
sent_tokenize(text, 'russian')
# Out:
# [nltk_data] Downloading package punkt to /home/postyakov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['\u200b«Новая газета» опубликовала сокращенный вариант заключения экспертов Александра Коршикова и Анны Осокиной, которые анализировали видео из блога студента Высшей школы экономики Егора Жукова, обвиняемого в призывах к экстремизму в интернете (часть 2 статьи 280 УК).',
#  'Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова.',
#  'По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».',
#  'В заключении говорится, что Жуков приписывает действующей власти «враждебные действия», называет ее врагами, источником зла и вреда.',
#  'Кроме того, студент призывает с этой властью бороться.',
#  '«Автор описывает катастрофическое положение населения в России, как следствие целенаправленной политики действующей власти <...>.',
#  'Основным идеалом, которого следует достичь, является "смена власти в России" для того, чтобы "Россия стала свободной"», — цитирует издание экспертов.',
#  'В одном из видео, в котором Жуков размышлял об итогах митинга 7 октября 2017 года, эксперты увидели призыв бороться любым способом, «что включает в себя и действия насильственного характера, в частности, насильственный захват власти, вооруженный мятеж».',
#  'Егор Жуков — фигурант «московского дела».',
#  'Сначала его обвиняли в участии в массовых беспорядках (часть 2 статьи 212 УК).',
#  'В суде говорили, что среди материалов есть видео, где Жуков показывает кому-то направо на акции 27 июля.',
#  'Из-за этого студента 2 августа отправили в СИЗО.',
#  'Однако через месяц дело о массовых беспорядках против Жукова закрыли, ему предъявили новое обвинение в призывах к экстремизму.',
#  'По ходатайстве следствие суд перевел студента под домашний арест.']

# %%
def word_tokenize(text):
  return re.findall('\w+', text)
print(word_tokenize(text))
# Out:
# ['Новая', 'газета', 'опубликовала', 'сокращенный', 'вариант', 'заключения', 'экспертов', 'Александра', 'Коршикова', 'и', 'Анны', 'Осокиной', 'которые', 'анализировали', 'видео', 'из', 'блога', 'студента', 'Высшей', 'школы', 'экономики', 'Егора', 'Жукова', 'обвиняемого', 'в', 'призывах', 'к', 'экстремизму', 'в', 'интернете', 'часть', '2', 'статьи', '280', 'УК', 'Эксперты', 'нашли', 'экстремизм', 'в', 'четырех', 'видео', 'на', 'YouTube', 'канале', 'Жукова', 'По', 'их', 'мнению', 'в', 'видео', 'отчетливо', 'прослеживается', 'мотив', 'политической', 'ненависти', 'или', 'вражды', 'к', 'действующей', 'власти', 'В', 'заключении', 'говорится', 'что', 'Жуков', 'приписывает', 'действующей', 'власти', 'враждебные', 'действия', 'называет', 'ее', 'врагами', 'источником', 'зла', 'и', 'вреда', 'Кроме', 'того', 'студент', 'призывает', 'с', 'этой', 'властью', 'бороться', 'Автор', 'описывает', 'катастрофическое', 'положение', 'населения', 'в', 'России', 'как', 'следствие', 'целенаправленной', 'политики', 'действующей', 'власти', 'Основным', 'идеалом', 'которого', 'следует', 'достичь', 'является', 'смена', 'власти', 'в', 'России', 'для', 'того', 'чтобы', 'Россия', 'стала', 'свободной', 'цитирует', 'издание', 'экспертов', 'В', 'одном', 'из', 'видео', 'в', 'котором', 'Жуков', 'размышлял', 'об', 'итогах', 'митинга', '7', 'октября', '2017', 'года', 'эксперты', 'увидели', 'призыв', 'бороться', 'любым', 'способом', 'что', 'включает', 'в', 'себя', 'и', 'действия', 'насильственного', 'характера', 'в', 'частности', 'насильственный', 'захват', 'власти', 'вооруженный', 'мятеж', 'Егор', 'Жуков', 'фигурант', 'московского', 'дела', 'Сначала', 'его', 'обвиняли', 'в', 'участии', 'в', 'массовых', 'беспорядках', 'часть', '2', 'статьи', '212', 'УК', 'В', 'суде', 'говорили', 'что', 'среди', 'материалов', 'есть', 'видео', 'где', 'Жуков', 'показывает', 'кому', 'то', 'направо', 'на', 'акции', '27', 'июля', 'Из', 'за', 'этого', 'студента', '2', 'августа', 'отправили', 'в', 'СИЗО', 'Однако', 'через', 'месяц', 'дело', 'о', 'массовых', 'беспорядках', 'против', 'Жукова', 'закрыли', 'ему', 'предъявили', 'новое', 'обвинение', 'в', 'призывах', 'к', 'экстремизму', 'По', 'ходатайстве', 'следствие', 'суд', 'перевел', 'студента', 'под', 'домашний', 'арест']

# %%
words_analized = [morph.parse(token) for token in word_tokenize(text)]

# %%
print(words_analized)
# Out:
# [[Parse(word='новая', tag=OpencorporaTag('ADJF,Qual femn,sing,nomn'), normal_form='новый', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'новая', 405, 7),))], [Parse(word='газета', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='газета', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'газета', 55, 0),))], [Parse(word='опубликовала', tag=OpencorporaTag('VERB,perf,tran femn,sing,past,indc'), normal_form='опубликовать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'опубликовала', 276, 2),))], [Parse(word='сокращённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv,Adjx masc,sing,nomn'), normal_form='сократить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'сокращённый', 858, 42),)), Parse(word='сокращённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv,Adjx inan,masc,sing,accs'), normal_form='сократить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'сокращённый', 858, 46),))], [Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='вариант', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 33, 0),)), Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='вариант', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 33, 3),)), Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='варианта', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 55, 8),))], [Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='заключение', score=0.967741, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 2),)), Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='заключение', score=0.016129, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 13),)), Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='заключение', score=0.016129, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 18),))], [Parse(word='экспертов', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='эксперт', score=0.78125, methods_stack=((<DictionaryAnalyzer>, 'экспертов', 52, 7),)), Parse(word='экспертов', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='эксперт', score=0.21875, methods_stack=((<DictionaryAnalyzer>, 'экспертов', 52, 9),))], [Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 1),)), Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 3),)), Parse(word='александра', tag=OpencorporaTag('NOUN,anim,femn,Name sing,nomn'), normal_form='александра', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 68, 0),))], [Parse(word='коршикова', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,nomn'), normal_form='коршикова', score=0.5002875215641174, methods_stack=((<DictionaryAnalyzer>, 'кова', 35, 0), (<UnknownPrefixAnalyzer>, 'корши'))), Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 1), (<KnownSuffixAnalyzer>, 'икова'))), Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,accs'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 3), (<KnownSuffixAnalyzer>, 'икова'))), Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,nomn'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 6), (<KnownSuffixAnalyzer>, 'икова'))), Parse(word='коршикова', tag=OpencorporaTag('ADJS femn,sing'), normal_form='коршиковый', score=0.028177113283496265, methods_stack=((<FakeDictionary>, 'коршикова', 72, 28), (<KnownSuffixAnal ...

# %%
mystem.lemmatize(text)
# Out:
# ['\u200b«',
#  'новый',
#  ' ',
#  'газета',
#  '» ',
#  'опубликовывать',
#  ' ',
#  'сокращать',
#  ' ',
#  'вариант',
#  ' ',
#  'заключение',
#  ' ',
#  'эксперт',
#  ' ',
#  'александр',
#  ' ',
#  'коршиков',
#  ' ',
#  'и',
#  ' ',
#  'анна',
#  ' ',
#  'осокина',
#  ', ',
#  'который',
#  ' ',
#  'анализировать',
#  ' ',
#  'видео',
#  ' ',
#  'из',
#  ' ',
#  'блог',
#  ' ',
#  'студент',
#  ' ',
#  'высокий',
#  ' ',
#  'школа',
#  ' ',
#  'экономика',
#  ' ',
#  'егор',
#  ' ',
#  'жуков',
#  ', ',
#  'обвиняемый',
#  ' ',
#  'в',
#  ' ',
#  'призыв',
#  ' ',
#  'к',
#  ' ',
#  'экстремизм',
#  ' ',
#  'в',
#  ' ',
#  'интернет',
#  ' (',
#  'часть',
#  ' ',
#  '2',
#  ' ',
#  'статья',
#  ' ',
#  '280',
#  ' ',
#  'ук',
#  ')',
#  '.',
#  '\n',
#  '\n',
#  'эксперт',
#  ' ',
#  'находить',
#  ' ',
#  'экстремизм',
#  ' ',
#  'в',
#  ' ',
#  'четыре',
#  ' ',
#  'видео',
#  ' ',
#  'на',
#  ' ',
#  'YouTube',
#  '-',
#  'канал',
#  ' ',
#  'жуков',
#  '. ',
#  'по',
#  ' ',
#  'их',
#  ' ',
#  'мнение',
#  ', ',
#  'в',
#  ' ',
#  'видео',
#  ' «',
#  'отчетливо',
#  ' ',
#  'прослеживаться',
#  ' ',
#  'мотив',
#  ' ',
#  'политический',
#  ' ',
#  'ненависть',
#  ' ',
#  'или',
#  ' ',
#  'вражда',
#  ' ',
#  'к',
#  ' ',
#  'действующий',
#  ' ',
#  'власть',
#  '»',
#  '.',
#  '\n',
#  '\n',
#  'в',
#  ' ',
#  'заключение',
#  ' ',
#  'говориться',
#  ', ',
#  'что',
#  ' ',
#  'жуков',
#  ' ',
#  'приписывать',
#  ' ',
#  'действующий',
#  ' ',
#  'власть',
#  ' «',
#  'враждебный',
#  ' ',
#  'действие',
#  '», ',
#  'называть',
#  ' ',
#  'ее',
#  ' ',
#  'враг',
#  ', ',
#  'источник',
#  ' ',
#  'зло',
#  ' ',
#  'и',
#  ' ',
#  'вред',
#  '. ',
#  'кроме',
#  ' ',
#  'то',
#  ', ',
#  'студент',
#  ' ',
#  'призывать',
#  ' ',
#  'с',
#  ' ',
#  'этот',
#  ' ',
#  'власть',
#  ' ',
#  'бороться',
#  '.',
#  '\n',
#  '\n',
#  '«',
#  'автор',
#  ' ',
#  'описывать',
#  ' ',
#  'катастрофический',
#  ' ',
#  'положение',
#  ' ',
#  'население',
#  ' ',
#  'в',
#  ' ',
#  'россия',
#  ', ',
#  'как',
#  ' ',
#  'следствие',
#  ' ',
#  'целенаправленный',
#  ' ',
#  'политика',
#  ' ',
#  'действовать',
#  ' ',
#  'власть',
#  ' <',
#  '...>. ',
#  'основной',
#  ' ',
#  'идеал',
#  ', ',
#  'который',
#  ' ',
#  'следовать',
#  ' ',
#  'достигать',
#  ', ',
#  'являться',
#  ' "',
#  'смена',
#  ' ',
#  'власть',
#  ' ',
#  'в',
#  ' ',
#  'россия',
#  '" ',
#  'для',
#  ' ',
#  'то',
#  ', ',
#  'чтобы',
#  ' "',
#  'россия',
#  ' ',
#  'становиться',
#  ' ',
#  'свободный',
#  '"», — ',
#  'цитировать',
#  ' ',
#  'издание',
#  ' ',
#  'эксперт',
#  '.',
#  '\n',
#  '\n',
#  'в',
#  ' ',
#  'один',
#  ' ',
#  'из',
#  ' ',
#  'видео',
#  ', ',
#  'в',
#  ' ',
#  'который',
#  ' ',
#  'жуков',
#  ' ',
#  'размышлять',
#  ' ',
#  'об',
#  ' ',
#  'итог',
#  ' ',
#  'митинг',
#  ' ',
#  '7',
#  ' ',
#  'октябрь',
#  ' ',
#  '2017',
#  ' ',
#  'год',
#  ', ',
#  'эксперт',
#  ' ',
#  'увидеть',
#  ' ',
#  'призыв',
#  ' ',
#  'бороться',
#  ' ',
#  'любой',
#  ' ',
#  'способ',
#  ', «',
#  'что',
#  ' ',
#  'включать',
#  ' ',
#  'в',
#  ' ',
#  'себя',
#  ' ',
#  'и',
#  ' ',
#  'действие',
#  ' ',
#  'насильственный',
#  ' ',
#  'характер',
#  ', ',
#  'в',
#  ' ',
#  'частность',
#  ', ',
#  'насильственный',
#  ' ',
#  'захват',
#  ' ',
#  'власть',
#  ', ',
#  'вооруженный',
#  ' ',
#  'мятеж',
#  '»',
#  '.',
#  '\n',
#  '\n',
#  'егор',
#  ' ',
#  'жуков',
#  ' — ',
#  'фигурант',
#  ' «',
#  'московский',
#  ' ',
#  'дело',
#  '»',
#  '. ',
#  'сначала',
#  ' ',
#  'он',
#  ' ',
#  'обвинять',
#  ' ',
#  'в',
#  ' ',
#  'участие',
#  ' ',
#  'в',
#  ' ',
#  'массовый',
#  ' ',
#  'беспорядок',
#  ' (',
#  'часть',
#  ' ',
#  '2',
#  ' ',
#  'статья',
#  ' ',
#  '212',
#  ' ',
#  'ук',
#  ')',
#  '. ',
#  'в',
#  ' ',
#  'суд',
#  ' ',
#  'говорить',
#  ', ',
#  'что',
#  ' ',
#  'среди',
#  ' ',
#  'материал',
#  ' ',
#  'быть',
#  ' ',
#  'видео',
#  ', ',
#  'где',
#  ' ',
#  'жуков',
#  ' ',
#  'показывать',
#  ' ',
#  'кто-то',
#  ' ',
#  'направо',
#  ' ',
#  'на',
#  ' ',
#  'акция',
#  ' ',
#  '27',
#  ' ',
#  'июль',
#  '. ',
#  'из-за',
#  ' ',
#  'этот',
#  ' ',
#  'студент',
#  ' ',
#  '2',
#  ' ',
#  'август',
#  ' ',
#  'отправлять',
#  ' ',
#  'в',
#  ' ',
#  'сизо',
#  '.',
#  '\n',
#  '\n',
#  'однако',
#  ' ',
#  'через',
#  ' ',
#  'месяц',
#  ' ',
#  'дело',
#  ' ',
#  'о',
#  ' ',
#  'массовый',
#  ' ',
#  'беспорядок',
#  ' ',
#  'против',
#  ' ',
#  'жуков',
#  ' ',
#  'закрывать',
#  ', ',
#  'он',
#  ' ',
#  'предъявлять',
#  ' ',
#  'новый',
#  ' ',
#  'обвинение',
#  ' ',
#  'в',
#  ' ',
#  'призыв',
#  ' ',
#  'к',
#  ' ',
#  'экстремизм',
#  '. ',
#  'по',
#  ' ',
#  'ходатайство',
#  ' ',
#  'следствие',
#  ' ',
#  'суд',
#  ' ',
#  'переводить',
#  ' ',
#  'студент',
#  ' ',
#  'под',
#  ' ',
#  'домашний',
#  ' ',
#  'арест',
#  '.',
#  '\n']

# %%
f = open('text.txt', 'w')
f.write(text1)
f.close()

# %%
os.system(' ./mystem -iscd --format json text.txt text_parsed.txt')
# Out:
# 0

# %%
t = [json.loads(line) for line in open('text_parsed.txt')]

# %%
''.join([word['text'] for word in t[2]]).split('\\s')
# Out:
# ['Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова. ',
#  'По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».\n']

# %% [markdown]
# 1.Mystem и sent_tokenize с данным текстом справились одинаково хорошо, поэтому сложно сказать, какой из способов лучше на данном примере.
# 2.Лучше в токенизации показал себя Mystem, регулярное выражение разбивает на два токена слова, которые пишутся через дефиc (например, "кто-то", "из-за").
# 3.Для лемматизации лучше использовать mystem, чем pymorphy2. Несмотря на то, что при использовании pymorphy2 не так много ошибок при лемматизации, однако в некоторых случаях заметно, что качество лемматизации mystem лучше (например, к слову "основным" mystem определяет лемму "основной", а pymorphy2 - "основный").
