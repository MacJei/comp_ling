# %% [markdown]
# <a href="https://colab.research.google.com/github/lnpetrova/comp_ling/blob/master/ML_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0432749d-b736-4822-91e0-d0720cff65d0" name="files[]" multiple disabled />
#      <output id="result-0432749d-b736-4822-91e0-d0720cff65d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weatherHistory.csv to weatherHistory.csv

# %%
weather_hist = pd.read_csv('weatherHistory.csv')

# %%
weather_hist.shape
# Out:
# (96453, 12)

# %%
weather_hist.head(5)
# Out:
#                   Formatted Date  ...                      Daily Summary
# 0  2006-04-01 00:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 1  2006-04-01 01:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 2  2006-04-01 02:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 3  2006-04-01 03:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 4  2006-04-01 04:00:00.000 +0200  ...  Partly cloudy throughout the day.
#
# [5 rows x 12 columns]

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
weather_hist.columns
# Out:
# Index(['date', 'Summary', 'weather_type', 'temp', 'temp_app', 'humidity',
#        'wind_speed', 'summary', 'visibility', 'wind_bearing', 'pressure'],
#       dtype='object')

# %%
weather_hist.rename({'Formatted Date':'date', 'Temperature (C)':'temp', 'Apparent Temperature (C)':'temp_app',
                    'Precip Type':'weather_type', 'Wind Speed (km/h)':'wind_speed', 'Humidity':'humidity',
                    'Daily Summary':'summary'}, 
                    axis=1, inplace=True)

# %%
weather_hist.head(20)
# Out:
#                          date        Summary weather_type       temp  \
# 0   2006-04-01 00:00:00+02:00  Partly Cloudy         rain   9.472222
# 1   2006-04-01 01:00:00+02:00  Partly Cloudy         rain   9.355556
# 2   2006-04-01 02:00:00+02:00  Mostly Cloudy         rain   9.377778
# 3   2006-04-01 03:00:00+02:00  Partly Cloudy         rain   8.288889
# 4   2006-04-01 04:00:00+02:00  Mostly Cloudy         rain   8.755556
# 5   2006-04-01 05:00:00+02:00  Partly Cloudy         rain   9.222222
# 6   2006-04-01 06:00:00+02:00  Partly Cloudy         rain   7.733333
# 7   2006-04-01 07:00:00+02:00  Partly Cloudy         rain   8.772222
# 8   2006-04-01 08:00:00+02:00  Partly Cloudy         rain  10.822222
# 9   2006-04-01 09:00:00+02:00  Partly Cloudy         rain  13.772222
# 10  2006-04-01 10:00:00+02:00  Partly Cloudy         rain  16.016667
# 11  2006-04-01 11:00:00+02:00  Partly Cloudy         rain  17.144444
# 12  2006-04-01 12:00:00+02:00  Partly Cloudy         rain  17.800000
# 13  2006-04-01 13:00:00+02:00  Partly Cloudy         rain  17.333333
# 14  2006-04-01 14:00:00+02:00  Partly Cloudy         rain  18.877778
# 15  2006-04-01 15:00:00+02:00  Partly Cloudy         rain  18.911111
# 16  2006-04-01 16:00:00+02:00  Partly Cloudy         rain  15.388889
# 17  2006-04-01 17:00:00+02:00  Mostly Cloudy         rain  15.550000
# 18  2006-04-01 18:00:00+02:00  Mostly Cloudy         rain  14.255556
# 19  2006-04-01 19:00:00+02:00  Mostly Cloudy         rain  13.144444
#
#      temp_app  humidity  wind_speed                            summary  \
# 0    7.388889      0.89     14.1197  Partly cloudy throughout the day.
# 1    7.227778      0.86     14.2646  Partly cloudy throughout the day.
# 2    9.377778      0.89      3.9284  Partly cloudy throughout the day.
# 3    5.944444      0.83     14.1036  Partly cloudy throughout the day.
# 4    6.977778      0.83     11.0446  Partly cloudy throughout the day.
# 5    7.111111      0.85     13.9587  Partly cloudy throughout the day.
# 6    5.522222      0.95     12.3648  Partly cloudy throughout the day.
# 7    6.527778      0.89     14.1519  Partly cloudy throughout the day.
# 8   10.822222      0.82     11.3183  Partly cloudy throughout the day.
# 9   13.772222      0.72     12.5258  Partly cloudy throughout the day.
# 10  16.016667      0.67     17.5651  Partly cloudy throughout the day.
# 11  17.144444      0.54     19.7869  Partly cloudy throughout the day.
# 12  17.800000      0.55     21.9443  Partly cloudy throughout the day.
# 13  17.333333      0.51     20.6885  Partly cloudy throughout the day.
# 14  18.877778      0.47     15.3755  Partly cloudy throughout the day.
# 15  18.911111      0.46     10.4006  Partly cloudy throughout the day.
# 16  15.388889      0.60     14.4095  Partly cloudy throughout the day.
# 17  15.550000      0.63     11.1573  Partly cloudy throughout the day.
# 18  14.255556      0.69      8.5169  Partly cloudy throughout the day.
# 19  13.144444      0.70      7.6314  Partly cloudy throughout the day.
#
#     visibility  wind_bearing  pressure
# 0      15.8263         251.0   1015.13
# 1      15.8263         259.0   1015.63
# 2      14.9569         204.0   1015.94
# 3      15.8263         269.0   1016.41
# 4      15.8263         259.0   1016.51
# 5      14.9569         258.0   1016.66
# 6       9.9820         259.0   1016.72
# 7       9.9820         260.0   1016.84
# 8       9.9820         259.0   1017.37
# 9       9.9820         279.0   1017.22
# 10     11.2056         290.0   1017.42
# 11     11.4471         316.0   1017.74
# 12     11.2700         281.0   1017.59
# 13     11.2700         289.0   1017.48
# 14     11.4471         262.0   1017.17
# 15     11.2700         288.0   1016.47
# 16     11.2700         251.0   1016.15
# 17     11.4471         230.0   1016.17
# 18     11.2056         163.0   1015.82
# 19     11.2056         139.0   1015.83

# %%
weather_hist['temp'].mean(), weather_hist['temp'].std()
# Out:
# (11.932678437511868, 9.551546320656923)

# %%
weather_hist['temp_app'].min(), weather_hist['temp_app'].max()
# Out:
# (-27.716666666666665, 39.344444444444434)

# %%
weather_hist.describe()
# Out:
#                temp      temp_app      humidity    wind_speed    visibility  \
# count  96453.000000  96453.000000  96453.000000  96453.000000  96453.000000
# mean      11.932678     10.855029      0.734899     10.810640     10.347325
# std        9.551546     10.696847      0.195473      6.913571      4.192123
# min      -21.822222    -27.716667      0.000000      0.000000      0.000000
# 25%        4.688889      2.311111      0.600000      5.828200      8.339800
# 50%       12.000000     12.000000      0.780000      9.965900     10.046400
# 75%       18.838889     18.838889      0.890000     14.135800     14.812000
# max       39.905556     39.344444      1.000000     63.852600     16.100000
#
#        wind_bearing      pressure
# count  96453.000000  96453.000000
# mean     187.509232   1003.235956
# std      107.383428    116.969906
# min        0.000000      0.000000
# 25%      116.000000   1011.900000
# 50%      180.000000   1016.450000
# 75%      290.000000   1021.090000
# max      359.000000   1046.380000

# %%
weather_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
# date            96453 non-null object
# Summary         96453 non-null object
# weather_type    95936 non-null object
# temp            96453 non-null float64
# temp_app        96453 non-null float64
# humidity        96453 non-null float64
# wind_speed      96453 non-null float64
# summary         96453 non-null object
# visibility      96453 non-null float64
# wind_bearing    96453 non-null float64
# pressure        96453 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 8.1+ MB

# %%
weather_hist.corr()
# Out:
#                   temp  temp_app  humidity  wind_speed  visibility  \
# temp          1.000000  0.992629 -0.632255    0.008957    0.392847
# temp_app      0.992629  1.000000 -0.602571   -0.056650    0.381718
# humidity     -0.632255 -0.602571  1.000000   -0.224951   -0.369173
# wind_speed    0.008957 -0.056650 -0.224951    1.000000    0.100749
# visibility    0.392847  0.381718 -0.369173    0.100749    1.000000
# wind_bearing  0.029988  0.029031  0.000735    0.103822    0.047594
# pressure     -0.005447 -0.000219  0.005454   -0.049263    0.059818
#
#               wind_bearing  pressure
# temp              0.029988 -0.005447
# temp_app          0.029031 -0.000219
# humidity          0.000735  0.005454
# wind_speed        0.103822 -0.049263
# visibility        0.047594  0.059818
# wind_bearing      1.000000 -0.011651
# pressure         -0.011651  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(data=weather_hist.corr(), 
            annot=True, ax=ax)
plt.title("Корреляция")
plt.show()

# %%
weather_hist['pressure'].value_counts()
# Out:
# 0.00       1288
# 1017.70     123
# 1015.00     119
# 1018.00     118
# 1015.80     118
#            ...
# 991.31        1
# 989.50        1
# 1038.54       1
# 1040.10       1
# 1000.84       1
# Name: pressure, Length: 4979, dtype: int64

# %%
weather_hist = weather_hist[weather_hist['pressure'] > 100]

# %%
weather_hist[weather_hist['pressure'] < 100]['pressure'] = weather_hist['pressure'].mean()

# %%
weather_hist.Summary.unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
weather_hist.groupby('Summary').agg(['mean'])
# Out:
#                                           temp   temp_app  humidity  \
#                                           mean       mean      mean
# Summary
# Breezy                               11.102963   7.196296  0.615667
# Breezy and Dry                       21.111111  21.111111  0.260000
# Breezy and Foggy                     -0.510317  -7.403492  0.938571
# Breezy and Mostly Cloudy             11.096695   8.683823  0.637495
# Breezy and Overcast                   7.245958   3.496635  0.762457
# Breezy and Partly Cloudy             12.404339   9.887877  0.544512
# Clear                                11.995976  11.164735  0.732495
# Dangerously Windy and Partly Cloudy   8.944444   3.483333  0.490000
# Drizzle                              10.847578  10.011681  0.867949
# Dry                                  29.083660  28.273529  0.230294
# Dry and Mostly Cloudy                26.838492  25.929365  0.242143
# Dry and Partly Cloudy                26.605749  25.982235  0.240814
# Foggy                                 1.433768  -0.242252  0.950874
# Humid and Mostly Cloudy              20.886389  20.886389  0.874250
# Humid and Overcast                   21.515079  21.515079  0.881429
# Humid and Partly Cloudy              21.568301  21.568301  0.848824
# Light Rain                           10.021517   8.560317  0.888095
# Mostly Cloudy                        12.634103  11.631332  0.724948
# Overcast                              7.501814   5.773298  0.837050
# Partly Cloudy                        16.019693  15.388384  0.648577
# Rain                                 10.096111   9.607222  0.947000
# Windy                                 4.994444  -0.866667  0.450000
# Windy and Dry                        27.222222  26.344444  0.240000
# Windy and Foggy                      11.876389   9.769444  0.900000
# Windy and Mostly Cloudy              11.807680   9.666176  0.597647
# Windy and Overcast                    7.932963   3.696543  0.708667
# Windy and Partly Cloudy               9.992504   6.515961  0.530159
#
#                                     wind_speed visibility wind_bearing  \
#                                           mean       mean         mean
# Summary
# Breezy                               31.323087  12.152280   240.100000
# Breezy and Dry                       33.810000   9.982000   240.000000
# Breezy and Foggy                     33.477880   1.621960   160.628571
# Breezy and Mostly Cloudy             33.371362  11.485255   227.107632
# Breezy and Overcast                  33.044560  11.084620   213.603810
# Breezy and Partly Cloudy             33.538127  11.334485   260.039578
# Clear                                 7.885603  11.722589   178.086794
# Dangerously Windy and Partly Cloudy  63.852600  11.447100   307.000000
# Drizzle                              10.356428   8.069815   177.307692
# Dry                                  14.713979  10.250965   230.294118
# Dry and Mostly Cloudy                13.667750  10.115400   187.785714
# Dry and Partly Cloudy                12.304519  10.987501   224.465116
# Foggy                                 7.171949   1.548952   168.790071
# Humid and Mostly Cloudy              10.058877   9.732852   153.425000
# Humid and Overcast                    9.740500   9.052800   138.857143
# Humid and Partly Cloudy               9.938435  10.633576   201.647059
# Light Rain                           14.673489   6.657989   180.761905
# Mostly Cloudy                        11.404808  11.121358   191.954471
# Overcast                             12.022803   9.282673   183.666950
# Partly Cloudy                        10.105709  11.816817   190.114549
# Rain                                  5.797610   1.779050   211.800000
# Windy                                42.536200  15.826300   340.000000
# Windy and Dry                        40.250000   9.982000   150.000000
# Windy and Foggy                      44.178400   1.903825   155.000000
# Windy and Mostly Cloudy              43.148000  11.192341   260.000000
# Windy and Overcast                   43.378409   9.806331   244.311111
# Windy and Partly Cloudy              44.579622  11.498722   293.698413
#
#                                         pressure
#                                             mean
# Summary
# Breezy                               1015.051667
# Breezy and Dry                       1021.600000
# Breezy and Foggy                     1008.934000
# Breezy and Mostly Cloudy             1010.413816
# Breezy and Overcast                  1007.841295
# Breezy and Partly Cloudy             1014.801346
# Clear                                1019.947339
# Dangerously Windy and Partly Cloudy  1009.050000
# Drizzle                              1014.931538
# Dry                                  1016.391765
# Dry and Mostly Cloudy                1014.872143
# Dry and Partly Cloudy                1017.242558
# Foggy                                1021.479827
# Humid and Mostly Cloudy              1012.887250
# Humid and Overcast                   1014.550000
# Humid and Partly Cloudy              1011.974118
# Light Rain                           1011.054762
# Mostly Cloudy                        1015.685106
# Overcast                             1015.112576
# Partly Cloudy                        1016.988956
# Rain                                 1017.318000
# Windy                                1019.010000
# Windy and Dry                        1020.200000
# Windy and Foggy                      1011.975000
# Windy and Mostly Cloudy              1008.643529
# Windy and Overcast                   1006.446000
# Windy and Partly Cloudy              1013.817619

# %%
weather_hist['date'] =  pd.to_datetime(weather_hist['date'], format='%Y-%m-%d %H:%M:%S +%f%z")
# Out:
#   File "<ipython-input-70-eaf7fb44aad5>", line 1
#     weather_hist['date'] =  pd.to_datetime(weather_hist['date'], format='%Y-%m-%d %H:%M:%S +%f%z")
#                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
weather_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95165 entries, 0 to 96452
# Data columns (total 11 columns):
# date            95165 non-null object
# Summary         95165 non-null object
# weather_type    94648 non-null object
# temp            95165 non-null float64
# temp_app        95165 non-null float64
# humidity        95165 non-null float64
# wind_speed      95165 non-null float64
# summary         95165 non-null object
# visibility      95165 non-null float64
# wind_bearing    95165 non-null float64
# pressure        95165 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 11.2+ MB

# %%
group_yeardays = weather_hist.groupby(['year','day_of_year', 'month', 'day']).agg('mean')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-9864046ec71c> in <module>()
# ----> 1 group_yeardays = weather_hist.groupby(['year','day_of_year', 'month', 'day']).agg('mean')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'year'
